# %% [markdown]
# # 1. String
# Strings in Python are sequences of characters enclosed in quotes (either single, double, or triple quotes for multiline strings). They can contain letters, numbers, and symbols

# %%
ggg = 1
print(ggg-2)
# Out:
# -1

# %%
# TO:DO
# Define actual your name as a string (using '' or "")
name = "BOber"

# Print the student name
print(name)
# Out:
# BOber

# %% [markdown]
# # 2. Integer
# Integers are whole numbers, which can be positive, negative, or zero, without a decimal point.

# %%
# TO:DO
# Define your age
age = 15
print(f"My age is {age}, next year it will be {age+1}")
# Out:
# My age is 15, next year it will be 16

# %% [markdown]
# # 3. Float
# Floats (floating-point numbers) are numbers with a decimal point or in exponential form.

# %%
# TO:DO
# Define your height in cm
height = 164.5
print(height)
# Out:
# 164.5

# %% [markdown]
# # 4. Boolean
# Booleans represent one of two values: `True` or `False`. They are the result of comparisons or conditions.

# %%
15==15.0
# Out:
# True

# %%
type(15), type(15.0), type(15) == type(15.0)
# Out:
# (int, float, False)

# %%
# If your age is equiled or above 18, in Ukraine you gonna be treated as adult
is_adult = age == 18
print(is_adult)
# Out:
# False

# %% [markdown]
# # 5. List
# Lists are ordered collections that are changeable and allow duplicate members. They are written with square brackets.

# %%
# TO:DO
# Write 3-5 your favourites movies
movies = ["The Shawshank Redemption", "Inception", "Spirited Away"]
print(movies)
# Out:
# ['The Shawshank Redemption', 'Inception', 'Spirited Away']

# %%
# TO:DO
# Print first and last movies in list
print(f"1st element in list: '{movies[0]}', 2nd - '{movies[1]}', last: '{movies[-1]}'")
# Out:
# 1st element in list: 'The Shawshank Redemption', 2nd - 'Inception', last: 'Spirited Away'

# %%
movies[1] = 'Panda KongFu'

# %%
movies
# Out:
# ['The Shawshank Redemption', 'Panda KongFu', 'Spirited Away']

# %%
# movies_tuple = {"The Shawshank Redemption", "Inception", "Spirited Away"}
# movies_tuple[1] = 'Panda KongFu'

# %%
movies + ['Cars 4']
# Out:
# ['The Shawshank Redemption', 'Panda KongFu', 'Spirited Away', 'Cars 4']

# %%
movies - ['Panda KongFu']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-70-1c1fd7ba3d65> in <cell line: 1>()
# ----> 1 movies - ['Panda KongFu']
#
# TypeError: unsupported operand type(s) for -: 'list' and 'list'

# %%
set(movies) - set(['Panda KongFu'])
# Out:
# {'Spirited Away', 'The Shawshank Redemption'}

# %% [markdown]
# # 6. Tuple
# Tuples are ordered collections that are unchangeable and allow duplicate members. They are written with parentheses.

# %%
# TO:DO
# Print colors
colors = ("red", "green", "blue", 'blue')
print(colors)
# Out:
# ('red', 'green', 'blue', 'blue')

# %%
colors[1] = 'violet'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-c29a3faa3244> in <cell line: 1>()
# ----> 1 colors[1] = 'violet'
#
# TypeError: 'tuple' object does not support item assignment

# %%
# TO:DO
# Try to redefine value for 1st element in tuple
colors[] =

# %% [markdown]
# When you attempt to run this code, Python will raise a **TypeError** because you're trying to modify a tuple,
# which is not allowed due to its immutable nature. The error message will look something like this:
# **TypeError**: 'tuple' object does not support item assignment
#
# So, it is OK to get an error - because you can not modify a tuple, but you can modify list or set

# %% [markdown]
# So, you have already met "TypeError".
#
# Other 7 most common errors we will discover next time:
# *   SyntaxError
# *   NameError
# *   IndexError
# *   KeyError
# *   ValueError
# *   AttributeError
# *   ZeroDivisionError

# %%
# TO:DO
# Define 3-5 your favourite car brands in a set
cars = set(["Lamborgini", "Tesla", "Toyota"])
print(cars)
# Out:
# {'Tesla', 'Lamborgini', 'Toyota'}

# %%
# TO:DO
# Check if you have some intersection of interest in car brands with bober
bobers_cars = {"Toyota", "Honda", "Ford"}
print(cars & bobers_cars)
# Out:
# {'Toyota'}

# %%
{"Toyota", "Honda", "Ford", "Ford"}
# Out:
# {'Ford', 'Honda', 'Toyota'}

# %% [markdown]
# # 8. Dictionary
# Dictionaries are unordered, changeable, and indexed collections. They have keys and values and are written with curly braces.

# %%
name = "Bober"

# %%
# TO:DO
# Get all data in single dict
person = {"name": name, "age": age, "height": height, "movies": movies}
print(person)
# Out:
# {'name': 'Bober', 'age': 15, 'height': 164.5, 'movies': ['The Shawshank Redemption', 'Panda KongFu', 'Spirited Away']}

# %%
person.keys()
# Out:
# dict_keys(['name', 'age', 'height', 'movies'])

# %%
person.values()
# Out:
# dict_values(['Olesia', 15, 164.0, ['The Shawshank Redemption', 'Panda KongFu', 'Spirited Away']])

# %%
# TO:DO
# Add one more pair of key/value for desired city to visit
person["dream city"] = 'Paris'
# print the updated dict
print(person)
# Out:
# {'name': 'Bober', 'age': 15, 'height': 164.5, 'movies': ['The Shawshank Redemption', 'Panda KongFu', 'Spirited Away'], 'dream city': 'Paris'}

# %%
person.keys()
# Out:
# dict_keys(['name', 'age', 'height', 'movies', 'dream city'])

# %%
person["name"]
# Out:
# 'Bober'

# %%
"fraud" in person
# Out:
# False

# %%
person["fraud"] = True

# %%
"fraud" in person
# Out:
# True

# %% [markdown]
# # Thank you for join the class! You are awesome, if you get here :D

# %%
{
  "survey_id": 123,
  "score": 9,
  "message": "amaze ... ",
  "response_id": 4
}
# Out:
# {'survey_id': 123, 'score': 9, 'message': 'amaze ... ', 'response_id': 4}
